# %%
import wikipedia as wp

# %%
# Let's search the first result of an "EPFL" query

an = wp.search("EPFL")[0]
pg = wp.page(an)
pg.title
# Out:
# 'École Polytechnique Fédérale de Lausanne'

# %%
# Its URL

pg.url
# Out:
# 'https://en.wikipedia.org/wiki/%C3%89cole_Polytechnique_F%C3%A9d%C3%A9rale_de_Lausanne'

# %%
# Its 100 first words

" ".join(pg.content.split(" ")[:100])
# Out:
# 'The École polytechnique fédérale de Lausanne (EPFL) is a research institute and university in Lausanne, Switzerland, that specializes in natural sciences and engineering. It is one of the two Swiss Federal Institutes of Technology, and it has three main missions: education, research and technology transferl.\nEPFL is located in the French-speaking part of Switzerland; the sister institution in the German-speaking part of Switzerland is the Swiss Federal Institute of Technology in Zurich (ETH Zurich). Associated with several specialised research institutes, the two universities form the Swiss Federal Institutes of Technology Domain (ETH Domain), which is directly dependent on the Federal Department'

# %%
# The links found in the page

pg.links
# Out:
# ['Aalborg University',
#  'Aalto University',
#  'Aart de Geus',
#  'Academic Ranking of World Universities',
#  'Adolphe Merkle Institute',
#  'Adrian Mihai Ionescu',
#  'Advanced Learning and Research Institute',
#  'Agence universitaire de la Francophonie',
#  'Agroscope',
#  'Ali H. Sayed',
#  'Alinghi',
#  'Amin Shokrollahi',
#  'Andrea Ablasser',
#  'André Borschberg',
#  'André Gorz',
#  'André Kudelski',
#  'Archimedean Oath',
#  'Archizoom (EPFL)',
#  'Aristotle University of Thessaloniki',
#  'Arjen Lenstra',
#  'BNF (identifier)',
#  'BWI Center for Industrial Management',
#  'Balelec Festival',
#  'Balloon (aircraft)',
#  'Basel',
#  'Basel Institute for Immunology',
#  'Bauman Moscow State Technical University',
#  'Ben-Gurion University of the Negev',
#  'Berlin Institute of Technology',
#  'Bern University of Applied Sciences',
#  'Bertrand Piccard',
#  'Bicycle sharing system',
#  'Big data',
#  'Biosafety level',
#  'Biowall',
#  'Blue Brain Project',
#  'Blue Gene',
#  'Boi Faltings',
#  'Breitling Orbiter',
#  'Breitling Orbiter 3',
#  'Brian Jones (aeronaut)',
#  'Brno University of Technology',
#  'Bruno Lemaitre',
#  'Budapest University of Technology and Economics',
#  'CERN',
#  'CLUSTER',
#  'CROCUS',
#  'CWTS Leiden Ranking',
#  'Campus Biotech',
#  'Carnegie Mellon University',
#  'Center for Comparative and International Studies',
#  'Centrale Graduate School',
#  'Centre for Finance and Development',
#  'Centre on Conflict, Development and Peacebuilding',
#  'Chalmers University of Technology',
#  'Circumnavigation',
#  'Claude Nicollier',
#  'Claudia R. Binder',
#  'College and university rankings',
#  'Comillas Pontifical University',
#  'Common European Framework of Reference for Languages',
#  'Community Université Grenoble Alpes',
#  'Conference of European Schools for Advanced Engineering Education and Research',
#  'Council of the European Union',
#  'Czech Technical University in Prague',
#  'DCAF',
#  'Dalle Molle Institute for Artificial Intelligence Research',
#  'Dalle Molle Institute for Semantic and Cognitive Studies',
#  'Daniel Borel',
#  'Daniel Brélaz',
#  'Daniel Thalmann',
#  'Dario Floreano',
#  'David Chipperfield',
#  'David Garrity',
#  'Delft University of Technology',
#  'Delta robot',
#  'Denis Duboule',
#  'Dorigny university campus',
#  'Dresden University of Technology',
#  'ENSTA ParisTech',
#  'EPFL',
#  'ETH Domain',
#  'ETH Library',
#  'ETH Zurich',
#  'Edouard Bugnion',
#  'Eduardo Souto de Moura',
#  'Erdős number',
#  'Eric Favre',
#  'European Federation of National Engineering Associations',
#  'European Professional Football Leagues',
#  'European Society for Engineering Education',
#  'European University Association',
#  'Eurotech Universities',
#  'Faculty of Engineering (LTH), Lund University',
#  'Faculté polytechnique de Mons',
#  'Federal Department of Economic Affairs, Education and Research',
#  'Federal Institute of Metrology',
#  'Fixed-wing aircraft',
#  'Francesco Mondada',
#  'Franck Riboud',
#  'Françoise Gisou van der Goot',
#  'French language',
#  'Fribourg',
#  'Friedrich Miescher Institute for Biomedical Research',
#  'Fusion energy',
#  'GND (identifier)',
#  'Gdańsk University of Technology',
#  'Geneva',
#  'Geneva Association',
#  'Geneva Centre for Security Policy',
#  'Geneva Water Hub',
#  'Geographic coordinate system',
#  'George de Mestral',
#  'Georges Meylan',
#  'German-speaking Switzerland',
#  'Ghent University',
#  'Giovanni De Micheli',
#  'Graz University of Technology',
#  'Green building on college campuses',
#  'Guy Berruyer',
#  'Henry Markram',
#  'Hippocratic Oath',
#  'Hubert Girault',
#  'Human Brain Project',
#  'Hydroptère',
#  'ISBN (identifier)',
#  'ISNI (identifier)',
#  'ISREC',
#  'Idiap Research Institute',
#  'Institut national des sciences Appliquées de Lyon',
#  "Institut supérieur de l'aéronautique et de l'espace",
#  'Institute for Mathematical Research',
#  'Institute for Virology und Immunology',
#  'Instituto Superior Técnico',
#  'International Academy of Sport Science and Technology',
#  'International Mountain Society',
#  'Istanbul Technical University',
#  'Jacques Dubochet',
#  'Jacques Lévy',
#  'James Larus',
#  'Jan S Hesthaven',
#  'Jean-Daniel Nicoud',
#  'Joseph Sifakis',
#  'János Pach',
#  'KOF (institute)',
#  'KTH Royal Institute of Technology',
#  'KU Leuven',
#  'Kalaidos University of Applied Sciences',
#  'Karen Scrivener',
#  'Karlsruhe Institute of Technology',
#  'Kaunas University of Technology',
#  'LCCN (identifier)',
#  'Lake Geneva',
#  'Lausanne',
#  'Lausanne Métro line 1',
#  'Lausanne campus',
#  'Leibniz University Hannover',
#  'List of universities in Switzerland',
#  'Lists of Presidents of École Polytechnique Fédérale de Lausanne',
#  'Logitech',
#  'Luc Recordon',
#  'Lucerne University of Applied Sciences and Arts',
#  'Luigi Snozzi',
#  'Lund University',
#  'Lyesse Laloui',
#  'Martin Odersky',
#  'Martin Vetterli',
#  'Maryna Viazovska',
#  'Massachusetts Institute of Technology',
#  'Matthias Lütolf',
#  'Mattia Binotto',
#  'Max Frisch Archive',
#  'Mediplant',
#  'Michael Grätzel',
#  'Minh Quang Tran',
#  'Montreux Jazz Festival',
#  'Moscow State Institute of Radio Engineering, Electronics and Automation',
#  'Mouse (computing)',
#  'Musée Bolo',
#  'Nagra',
#  'Name and Title Authority File of Catalonia',
#  'Nanocem',
#  'National Library of Australia',
#  'National Library of the Czech Republic',
#  'National Technical University of Athens',
#  'Nespresso',
#  'Nestlé',
#  'Neuchâtel',
#  'New University of Lisbon',
#  'Nicolas Monod',
#  'Nobel Prize in Chemistry',
#  'Norwegian University of Science and Technology',
#  'Nuclear reactor',
#  'Oeschger Centre for Climate Change Research',
#  'Othman Benjelloun',
#  'ParisTech',
#  'Patrick Aebischer',
#  'Paul Scherrer Institute',
#  'Polar Satellite Launch Vehicle',
#  'Politecnico di Milano',
#  'Politehnica University of Bucharest',
#  'Polytechnic University of Catalonia',
#  'Polytechnic University of Milan',
#  'Polytechnic University of Turin',
#  'Polytechnic University of Valencia',
#  'Postgraduate education',
#  'Poznań University of Technology',
#  'Presses polytechniques et universitaires romandes',
#  'Pritzker Prize',
#  'Public university',
#  'QS World University Rankings',
#  "Queen's University Belfast",
#  'RWTH Aachen University',
#  'Raptor code',
#  'Ras al-Khaimah',
#  'Research Institute of Organic Agriculture',
#  'Research reactor',
#  'Reymond Clavel',
#  'Riga Technical University',
#  'Rolex Learning Center',
#  'Royal Institute of Technology',
#  'SUDOC (identifier)',
#  'SUPSI',
#  'Sage Group',
#  'Satellite',
#  'Scala (programming language)',
#  'School colors',
#  'Science and technology in Switzerland',
#  'Scuderia Ferrari',
#  'Serge Vaudenay',
#  'Sion, Switzerland',
#  'Solar Impulse',
#  'Solar Impulse project',
#  'Solar power',
#  'Sphere packing',
#  'Stefan Kudelski',
#  'Suisse Romande',
#  'Supélec',
#  'SwissCube-1',
#  'SwissTech Convention Center',
#  'Swiss Academies of Arts and Sciences',
#  'Swiss Academy of Engineering Sciences',
#  'Swiss Academy of Humanities and Social Sciences',
#  'Swiss Academy of Medical Sciences',
#  'Swiss Academy of Natural Sciences',
#  'Swiss Cancer Centre',
#  'Swiss Cube 1',
#  'Swiss Electromagnetics Research and Engineering Centre',
#  'Swiss Federal Institute for Forest, Snow and Landscape Research',
#  'Swiss Federal Institute of Aquatic Science and Technology',
#  'Swiss Federal Institute of Technology Domain',
#  'Swiss Federal Laboratories for Materials Science and Technology',
#  'Swiss Finance Institute',
#  'Swiss Innovation Park',
#  'Swiss Institute for Experimental Cancer Research',
#  'Swiss Institute of Bioinformatics',
#  'Swiss Laboratory for Doping Analyses',
#  'Swiss Nanoscience Institute',
#  'Swiss National Supercomputing Centre',
#  'Swiss Ornithological Institute',
#  'Swiss Tech Convention Center',
#  'Swiss University Conference',
#  'Swiss cantons',
#  'Swiss franc',
#  'Swiss red',
#  'Switzerland',
#  'Synopsys',
#  'TU Wien',
#  'Tallinn University of Technology',
#  'Technical University of Berlin',
#  'Technical University of Braunschweig',
#  'Technical University of Denmark',
#  'Technical University of Madrid',
#  'Technion – Israel Institute of Technology',
#  'Technische Universität Darmstadt',
#  'Technische Universität München',
#  'Technologist (magazine)',
#  'The European Space Agency',
#  'Times Higher Education World University Rankings',
#  'Tokamak',
#  'Tokamak à configuration variable',
#  'Tomsk Polytechnic University',
#  'Top Industrial Managers for Europe',
#  'Top International Managers in Engineering',
#  'U.S. News & World Report Best Colleges Ranking',
#  'UNESCO',
#  'Undergraduate education',
#  'United Arab Emirates',
#  'University College Dublin',
#  'University of Applied Sciences Western Switzerland',
#  'University of Applied Sciences of Eastern Switzerland',
#  'University of Basel',
#  'University of Bern',
#  'University of Erlangen-Nuremberg',
#  'University of Fort Hare',
#  'University of Fribourg',
#  'University of Geneva',
#  'University of Hannover',
#  'University of Lausanne',
#  'University of Liège',
#  'University of Lucerne',
#  'University of Nairobi',
#  'University of Neuchâtel',
#  'University of Padua',
#  'University of Paris-Saclay',
#  'University of Porto',
#  'University of Seville',
#  'University of Sheffield',
#  'University of St. Gallen',
#  'University of Strathclyde',
#  'University of Stuttgart',
#  'University of Surrey',
#  'University of Tokyo',
#  'University of Trento',
#  'University of Twente',
#  'University of Yaounde',
#  'University of Zurich',
#  'Università della Svizzera italiana',
#  'Université catholique de Louvain',
#  'Université libre de Bruxelles',
#  'VIAF (identifier)',
#  'VMware',
#  'Vaud',
#  'Velcro',
#  'Venice Time Machine',
#  'Vrije Universiteit Brussel',
#  'Warsaw University of Technology',
#  'WorldCat Identities (identifier)',
#  'World Trade Institute',
#  'Wrocław University of Technology',
#  'Wyss Center for Bio- and Neuro-engineering',
#  'Wyss Center for Bio and Neuroengineering',
#  'YouTube',
#  'Zurich University of Applied Sciences',
#  'Zurich University of Applied Sciences/ZHAW',
#  'Zurich University of Applied Sciences in Business Administration',
#  'Zurich University of the Arts',
#  'Álvaro Siza Vieira',
#  'École Centrale Paris',
#  'École Centrale de Lille',
#  'École Centrale de Lyon',
#  "École cantonale d'art de Lausanne",
#  'École centrale de Marseille',
#  'École centrale de Nantes',
#  'École des Ponts ParisTech',
#  "École nationale supérieure de l'aéronautique et de l'espace",
#  'École polytechnique',
#  'Écublens, Vaud']

# %%
# How about the 10 first sentences in the French article in French?

wp.set_lang("fr")
pg = wp.search(an)
wp.summary(pg, sentences=6)
# Out:
# 'Il existe deux filières de formation des ingénieurs diplômésen Suisse :\n\nles écoles polytechniques fédérales (EPF) ou ETH (allemand)\nles hautes écoles spécialisées ou HES.Les deux filières se distinguent par leur enseignement: les écoles polytechniques se concentrent sur les sciences fondamentales et les hautes écoles spécialisées sur les sciences appliquées.\n\n\n== École polytechnique ==\nL\'École polytechnique fédérale de Lausanne (EPFL)\nL\'École polytechnique fédérale de Zurich (ETHZ)\n\n\n== Haute école spécialisée ==\nLes sections "technologie et ingénierie" des Hautes écoles spécialisées suisses.\n\n\n== Accès ==\nEPF (en allemand : ETH) :\n\nMaturité gymnasiale ou professionnelle technique\nDiplômes étrangers équivalents\nMaturité professionnelle  (après une année préparatoire)HES :\n\nMaturité professionnelle technique\nMaturité gymnasiale (après année préparatoire, année de connaissances professionnelles)\nDiplôme de technicien ES\nCertificat fédéral de capacité (avec examen d\'entrée)\nDiplômes étrangers équivalents\n\n\n== Diplômes ==\nEn Suisse, le titre d\'ingénieur est obtenu à partir du Bachelor of Sciences⁴ pour les HES, soit 3 années après la maturité (bac+3) contrairement à beaucoup de pays comme la France qui décernent le titre d\'ingénieur seulement après un Master of sciences⁴ (bac+5). Dans les cas d\'un diplôme d\'une EPF, le titre est obtenu à partir du Master of Sciences, soit 4.5 à 5 années après la maturité (bac+5).\nCeci est dû, pour les HES, au fait que l\'entrée en école d\'ingénieurs est réservée aux porteurs d\'une maturité professionnelle technique qui possèdent déjà un bagage de connaissances techniques et d\'expériences en entreprise. Il est néanmoins possible pour les porteurs d\'une maturité gymnasiale (bac général) d\'y accéder en effectuant une année préparatoire de cours techniques (systèmes logiques ou électronique numérique, électrotechnique, CAO, matériaux, etc.).'

# %%
# Now let's see how many articles we can get for a query

occurences = wp.search("EPFL", results=10000)
print("wikipedia.search only returns a maximum of", len(occurences), "occurences even when asked for 10'000.")
# Out:
# wikipedia.search only returns a maximum of 500 occurences even when asked for 10'000.

# %% [markdown]
# Python's `wikipedia` module is not intended for big data uses as seen above. The `wikipedia.search` function will only return the first 500 occurences of a word, which is not appropriate. We will thus use Pywikibot from https://pywikibot.toolforge.org/

# %%
an = wp.search("EPFL")[0]
pg = wp.page(an)
print(pg.links)
# Out:
# ['1853', '1869', '1890', '1943', '1946', '1969', '1974', '1978', '2009', '2017', '20 km de Lausanne', 'Aart de Geus', 'Adrien Palaz', 'Agence universitaire de la Francophonie', 'Ahmed Zewail', 'Al Gore', 'Alain Fuchs', 'Alfred Stucky', 'Alinghi', 'Allemand', 'Alvaro Siza', 'Ancien évêché de Lausanne', 'André Borschberg', 'André Gorz', 'André Kudelski', 'Anglais', 'Année de propédeutique', 'Années 2000', 'Antonio Damasio', 'Arjen Lenstra', 'Artlab', 'Arun Netravali', 'Association des universités européennes', 'Avion solaire', 'Baccalauréat (scolaire)', 'Baccalauréat universitaire en sciences', 'Beat Richner', 'Beaulieu/Grey/Boisy', 'Bernard Huet', 'Bernard Vittoz', 'Bertrand Piccard', 'Bibliothèque cantonale et universitaire - Lausanne', 'Big data', 'Biologie', 'Blue Brain', 'Blue Gene', 'Bois-Mermet', 'Bois de Sauvabelin', 'Bonnie Berger', 'Borde/Bellevaux', 'Bossons/Blécherette', 'Boulevard de Grancy', 'Breitling Orbiter 3', 'Brevet fédéral', 'Brian Jones (aérostier)', 'Béjart Ballet Lausanne', 'Campus Biotech', 'Campus de Lausanne', 'Canal+', 'Canton de Genève', 'Canton de Neuchâtel', 'Canton de Vaud', 'Canton du Valais', 'Canton suisse', 'Capitole (cinéma)', 'Carla J. Shatz', 'Casino de Montbenon', 'Catherine Bréchignac', 'Cathédrale de Lausanne', 'Cellule Grätzel', 'Centre (Lausanne)', 'Centre de formation professionnelle santé et social', 'Centre hospitalier universitaire vaudois', 'Chailly/Rovéréaz', 'Chalet-des-Enfants', 'Charles Dapples', 'Charles Weissmann', 'Chief Executive Officer', 'Christian Menn', 'Christos Papadimitriou', 'Château Saint-Maire', "Château d'Ouchy", 'Cimetière de Montoie', 'Cimetière du Bois-de-Vaux', 'Cinémathèque suisse', 'Classe préparatoire aux grandes écoles', 'Classement mondial des universités QS', 'Claude Nicollier', 'Claude Nobs', 'Claudia de Rham', 'Claudie Haigneré', 'Club des patineurs de Lausanne', "Collection de l'art brut", 'Colline de la Cité', 'Colonne corticale', 'Comité international de la Croix-Rouge', "Commission des titres d'ingénieur", 'Conseil européen de la recherche', 'Conservatoire de Lausanne', 'Consortium Linking Universities of Science and Technology for Education and Research', 'CubeSat', 'Cynthia Barnhart', 'Daniel Borel', 'Daniel Brélaz', 'Daphne Koller', 'David Donoho', 'David Forney', 'Deborah Estrin', 'Dictionnaire historique de la Suisse', 'Diplôme fédéral', 'Doctorat en sciences', 'Domaine des Écoles polytechniques fédérales', 'EPFL+ECAL Lab', 'EPFL (homonymie)', 'EPFL (métro de Lausanne)', 'ETHZ', 'Elliott Lieb', 'Emmanuelle Charpentier', 'Espace Arlaud', 'Esplanade de Montbenon', 'Fabiola Gianotti', 'Fachhochschule Nordwestschweiz', 'Fachhochschule Ostschweiz', 'Festival Balélec', 'Florimont/Chissiez', "Fondation de l'Hermitage", 'Fonds national suisse de la recherche scientifique', 'Football Club Lausanne-Sport', 'Football Club Le Mont-sur-Lausanne', 'Football Club Stade Lausanne Ouchy', 'Formation continue', "Formation d'ingénieur en Suisse", 'Franc suisse', 'Franck Riboud', 'Français', 'Françoise Barré-Sinoussi', 'Frederik Paulsen (fils)', 'Fribourg (canton)', 'Fribourg (ville suisse)', 'Fréquence Banane', 'GNUWin II', 'Galeries Saint-François', 'Gare de Lausanne', 'Gare de Lausanne-Flon', 'Genève', 'George de Mestral', 'Giovanni De Micheli', 'Grand-Pont (Lausanne)', 'Green 500', 'Greg Behar', 'Groupe P5+1', 'Hanna Damasio', 'Hansjörg Wyss', 'Haute École de Lucerne', 'Haute École pédagogique du canton de Vaud', 'Haute École spécialisée bernoise', 'Haute École spécialisée de Suisse occidentale', 'Haute école pédagogique', 'Haute école pédagogique - BEJUNE', 'Haute école pédagogique du Valais', 'Haute école spécialisée (Suisse)', 'Henri Rieben', 'Hockey Club La Villa Lausanne', 'Hugo Thiemann', 'Human Brain Project', 'Humanités digitales', 'Hydroptère.ch', 'Hôtel Beau-Rivage Palace', 'Hôtel de ville de Lausanne', 'Hôtel des postes de Lausanne', 'ITER', 'Imperial College London', "Incubateur d'entreprises", 'Indians Lausanne Baseball Club', 'Ingrid Daubechies ...

# %%
[x[:100] for x in pg.html().split('href="h')]
# Out:
# ['<div class="mw-parser-output"><div class="bandeau-container homonymie plainlinks"><div class="bandea',
#  'ttps://fr.wikipedia.org/w/index.php?title=%C3%89cole_polytechnique_f%C3%A9d%C3%A9rale_de_Lausanne&am',
#  'ttps://www.wikidata.org/wiki/Q262760?uselang=fr#P488" title="Voir et modifier les données sur Wikida',
#  'ttps://www.wikidata.org/wiki/Q262760?uselang=fr#P131" title="Voir et modifier les données sur Wikida',
#  'ttp://www.epfl.ch">www.epfl.ch</a></div></td></tr></tbody></table><p class="navbar noprint bordered"',
#  'ttps://fr.wikipedia.org/w/index.php?title=%C3%89cole_polytechnique_f%C3%A9d%C3%A9rale_de_Lausanne&am',
#  'ttps://fr.wikipedia.org/w/index.php?title=%C3%89cole_polytechnique_f%C3%A9d%C3%A9rale_de_Lausanne&am',
#  'ttps://www.wikidata.org/wiki/Q262760" class="extiw" title="d:Q262760">modifier Wikidata</a></span><s',
#  'ttps://en.wikipedia.org/wiki/John_A._Rogers" class="extiw" title="en:John A. Rogers"><span class="in',
#  'ttps://en.wikipedia.org/wiki/Hanna_Damasio" class="extiw" title="en:Hanna Damasio"><span class="indi',
#  'ttps://en.wikipedia.org/wiki/Roberto_Car" class="extiw" title="en:Roberto Car"><span class="indicate',
#  'ttps://en.wikipedia.org/wiki/Subra_Suresh" class="extiw" title="en:Subra Suresh"><span class="indica',
#  'ttps://en.wikipedia.org/wiki/David_Forney" class="extiw" title="en:David Forney"><span class="indica',
#  'ttps://en.wikipedia.org/wiki/Arun_Netravali" class="extiw" title="en:Arun Netravali"><span class="in',
#  'ttps://information.epfl.ch/chiffres">«&#160;<cite style="font-style:normal;">EPFL en chiffres</cite>',
#  'ttps://information.epfl.ch/files/content/sites/accueil/files/chiffres/2017/Personnes%202017.pdf">Per',
#  'ttps://information.epfl.ch/files/content/sites/accueil/files/chiffres/2017/Etudiants%202017.pdf">Étu',
#  'ttp://information.epfl.ch/en-bref">«&#160;<cite style="font-style:normal;">l\'EPFL en bref</cite>&#16',
#  'ttp://www.swissinfo.ch/fre/de-l-ecole-sp%C3%A9ciale-de-lausanne-%C3%A0-l-epfl/3242132">lire en ligne',
#  'ttp://information.epfl.ch/chiffres">«&#160;<cite style="font-style:normal;">statistiques epfl</cite>',
#  'ttp://www.epfl.ch">http://www.epfl.ch</a></span></span></span>\n</li>\n<li id="cite_note-10"><span cla',
#  'ttp://information.epfl.ch/chiffres">http://information.epfl.ch/chiffres</a></span>\n</li>\n<li id="cit',
#  'ttp://www.24heures.ch/vaud-regions/fois-epfl/story/14694343">lire en ligne</a>, consulté le <span cl',
#  'ttps://www.tdg.ch/suisse/L-EPFL-est-la-meilleure-des-jeunes-universites/story/31664353">lire en lign',
#  'ttp://www.romandie.com/news/L039EPFL-est-la-meilleure-des-jeunes/692406.rom">lire en ligne</a>, cons',
#  'ttp://sv.epfl.ch/mission">[1]</a> (page consultée le 4 octobre 2012).</span>\n</li>\n<li id="cite_note',
#  'ttp://www.formation-continue-unil-epfl.ch">Formation continue UNIL-EPFL</a> (page consultée le 19 no',
#  'ttp://presentation.epfl.ch/page7679.html">«&#160;<cite style="font-style:normal;">présentation epfl<',
#  'ttp://information.epfl.ch/chiffres">«&#160;<cite style="font-style:normal;">EPFL en chiffres</cite>&',
#  'ttp://sae.epfl.ch/page21928.html">«&#160;<cite style="font-style:normal;">Écoles partenaires</cite>&',
#  'ttp://epfl.ch">http://epfl.ch</a></span></span></span>\n</li>\n<li id="cite_note-19"><span class="mw-c',
#  'ttps://mediacom.epfl.ch/epfl-magazine">https://mediacom.epfl.ch/epfl-magazine</a> (page consultée le',
#  'ttp://www.auditoire.ch">http://www.auditoire.ch</a> (page consultée le 28 juillet 2016).</span>\n</li',
#  'ttp://www.rts.ch/archives/tv/information/affaires-publiques/6568739-un-site-d-excellence.html">lire ',
#  'ttp://actualites.epfl.ch/presseinfo-com?id=867">«&#160;<cite style="font-style:normal;">Communiqué d',
#  'ttp://actualites.epfl.ch">http://actualites.epfl.ch</a></span></span></span>\n</li>\n<li id="cite_note',
#  'ttp://actualites.epfl.ch/index.php?module=procontent&amp;func=display&amp;id=2291">«&#160;<cite styl',
#  'ttp://actualites.epfl.ch">http://actualites.epfl.ch</a></span></span></span>\n</li>\n<li id="cite_note',
#  'ttp://www.unil.ch/sport">Centre sportif universitaire de Dorigny</a> (page consultée le 20 mai 2012)',
#  'ttp://actualites.epfl.ch/presseinfo-com?id=931">«&#160;<cite style="font-style:normal;">Communiqué d',
#  'ttp://actualites.epfl.ch">http://actualites.epfl.ch</a></span></span></span>\n</li>\n<li id="cite_note',
#  'ttps://www.legifrance.gouv.fr/jo_pdf.do?numJO=0&amp;dateJO=19491022&amp;numTexte=&amp;pageDebut=1061',
#  'ttps://www.epfl.ch/education/master/fr/doubles-diplomes/">«&#160;<cite style="font-style:normal;">Do',
#  'ttp://sae.epfl.ch/ecoles-partenaires">«&#160;<cite style="font-style:normal;">Ecoles Partenaires EPF',
#  'ttp://sae.epfl.ch/page-27051-fr.html">«&#160;<cite style="font-style:normal;">statistiques sur l\'éch',
#  'ttp://sae.epfl.ch">http://sae.epfl.ch</a></span></span></span>\n</li>\n<li id="cite_note-30"><span cla',
#  'ttps://man.epfl.ch/">«&#160;<cite style="font-style:normal;">MAN | EPFL</cite>&#160;»</a>, sur <span',
#  'ttps://man.epfl.ch/files/content/sites/man/files/accueil.pdf">https://man.epfl.ch/files/content/site',
#  'ttps://www.radiolac.ch/actualite/le-man-le-cours-de-mise-a-niveau-de-lepfl-declare-illegal/">lire en',
#  'ttps://www.24heures.ch/vaud-regions/Attaque-de-toutes-parts-le-cours-de-mise-a-niveau-de-l-EPFL-vaci',
#  'ttp://bachelor.epfl.ch/admission-premiere-annee">http://bachelor.epfl.ch/admission-premiere-annee</a',
#  'ttp://bachelor.epfl.ch/admission-cpge">«&#160;<cite style="font-style:normal;">Conditions d\'admissio',
#  'ttp://bachelor.epfl.ch">http://bachelor.epfl.ch</a></span></span></span>\n</li>\n<li id="cite_note-36"',
#  'ttp://bachelor.epfl.ch/page37260.html">«&#160;<cite style="font-style:normal;">Admission en 3<sup>e<',
#  'ttp://bachelor.epfl.ch">http://bachelor.epfl.ch</a></span></span></span>\n</li>\n<li id="cite_note-37"',
#  'ttp://direction.epfl.ch/">«&#160;<cite style="font-style:normal;">Direction de l\'EPFL</cite>&#160;»<',
#  'ttp://www.epfl.ch">http://www.epfl.ch</a></span></span></span>\n</li>\n<li id="cite_note-timeshigher-3',
#  'ttps://www.timeshighereducation.co.uk/world-university-rankings/2015/subject-ranking/engineering-and',
#  'ttps://www.timeshighereducation.co.uk/world-university-rankings/2015/world-ranking/#/">«&#160;<cite ',
#  'ttp://www.topuniversities.com/university-rankings/faculty-rankings/natural-sciences/2014#sorting=ran',
#  'ttp://www.topuniversities.com/university-rankings/world-university-rankings/2014">«&#160;<cite style',
#  'ttp://www.topuniversities.com">http://www.topuniversities.com</a></span></span><span class="ouvrage"',
#  'ttp://www.topuniversities.com/university-rankings/faculty-rankings/engineering-and-technology/2014#s',
#  'ttp://www.topuniversities.com/university-rankings/faculty-rankings/natural-sciences/2014#sorting=ran',
#  'ttp://www.leidenranking.com/ranking/2015?sizeIndependant=True">«&#160;<cite style="font-style:normal',
#  'ttp://www.shanghairanking.com/ARWU2014.html">«&#160;<cite style="font-style:normal;">Classement de S',
#  'ttp://www.shanghairanking.com">http://www.shanghairanking.com</a></span></span></span>\n</li>\n<li id=',
#  'ttp://www.shanghairanking.com/FieldENG2014.html">«&#160;<cite style="font-style:normal;">Classement ',
#  'ttp://www.shanghairanking.com">http://www.shanghairanking.com</a></span></span></span>\n</li>\n<li id=',
#  'ttp://information.epfl.ch/chiffres/recherche">«&#160;<cite style="font-style:normal;">Statistique su',
#  'ttp://epfl.ch">http://epfl.ch</a></span></span></span>\n</li>\n<li id="cite_note-46"><span class="mw-c',
#  'ttp://actualites.epfl.ch/newspaper-article?np_id=1785&amp;np_eid=129">«&#160;<cite style="font-style',
#  'ttp://epfl.ch">http://epfl.ch</a></span></span></span>\n</li>\n<li id="cite_note-47"><span class="mw-c',
#  'ttp://www.top500.org/list/2012/11/?page=2">«&#160;<cite style="font-style:normal;">List - novembre 2',
#  'ttp://top500.org">http://top500.org</a></span></span></span>\n</li>\n<li id="cite_note-48"><span class',
#  'ttp://www.green500.org/lists/green201211">«&#160;<cite style="font-style:normal;">List - novembre 20',
#  'ttp://www.green500.org">http://www.green500.org</a></span></span></span>\n</li>\n<li id="cite_note-49"',
#  'ttp://hydroptere.epfl.ch/">«&#160;<cite style="font-style:normal;">Site de la collaboration EPFL-Hyd',
#  'ttp://swisscube.epfl.ch">«&#160;<cite style="font-style:normal;">SwissCube Website</cite>&#160;»</a>',
#  'ttp://www.humanbrainproject.eu">Site du Projet cerveau humain</a> (page consultée le 4 octobre 2012)',
#  'ttps://datascience.ch/">«&#160;<cite style="font-style:normal;">SDSC - A complex journey made simple',
#  'ttps://actu.epfl.ch/news/la-suisse-se-dote-d-un-centre-national-de-la-scien/">lire en ligne</a>, con',
#  'ttps://www.rts.ch/info/sciences-tech/9187692-l-epfl-annonce-la-creation-d-un-centre-pour-la-confianc',
#  'ttp://www.cibm.ch">Centre d\'imagerie biomédicale</a> (page consultée le 2 octobre 2011).</span>\n</li',
#  'ttp://www.cadmos.org">CADMOS</a> (page consultée le 20 février 2012).</span>\n</li>\n<li id="cite_note',
#  'ttps://www.epflalumni.ch/">«&#160;<cite style="font-style:normal;">EPFL Alumni</cite>&#160;»</a>, su',
#  'ttp://actualites.epfl.ch/newspaper-article?np_id=1450&amp;np_eid=101&amp;catid=107">«&#160;<cite sty',
#  'ttps://associations.epfl.ch/page-16300-fr-html/">«&#160;<cite style="font-style:normal;">Liste des a',
#  'ttp://epfl.ch">http://epfl.ch</a></span></span></span>\n</li>\n<li id="cite_note-60"><span class="mw-c',
#  'ttp://www.tink.ch/nouveau/article/2011/05/02/balelec-tempete-de-son-sur-lepfl/">http://www.tink.ch/n',
#  'ttp://www.polylan.ch">«&#160;<cite style="font-style:normal;">PolyLAN - La plus grande LAN de Suisse',
#  'ttps://commons.wikimedia.org/wiki/Category:%C3%89cole_Polytechnique_F%C3%A9d%C3%A9rale_de_Lausanne?u',
#  'ttp://www.epfl.ch">Site officiel</a></li>\n<li><a rel="nofollow" class="external text" ',
#  'ttp://www.epfl.ae">Site officiel du campus au Moyen-Orient</a></li>\n<li>Peter Fleer, Hans Werner Tob',
#  'ttps://hls-dhs-dss.ch/fr/articles/010419/"><span title="Ecoles polytechniques fédérales en français"',
#  'ttps://fr.wikipedia.org/w/index.php?title=Mod%C3%A8le:Palette_Lausanne&amp;action=edit"><abbr class=',
#  'ttps://fr.wikipedia.org/w/index.php?title=Mod%C3%A8le:Palette_%C3%89tudes_sup%C3%A9rieures_en_Suisse',
#  'ttps://de.wikipedia.org/wiki/Fachhochschule_Nordwestschweiz" class="extiw" title="de:Fachhochschule ',
#  'ttps://de.wikipedia.org/wiki/Z%C3%BCrcher_Fachhochschule" class="extiw" title="de:Zürcher Fachhochsc',
#  'ttps://it.wikipedia.org/wiki/Scuola_universitaria_professionale_della_Svizzera_italiana" class="exti',
#  'ttps://de.wikipedia.org/wiki/P%C3%A4dagogische_Hochschule_Wallis" class="extiw" title="de:Pädagogisc']
